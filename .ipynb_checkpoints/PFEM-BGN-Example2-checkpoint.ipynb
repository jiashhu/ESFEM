# %%
from ngsolve import *
import netgen.gui
import time
# Out:
# optfile ./ng.opt does not exist - using default values
# togl-version : 2
# OCC module loaded
# loading ngsolve library
# NGSolve-6.2.2105
# Using Lapack
# Including sparse direct solver Pardiso
# Running parallel using 8 thread(s)

# %% [markdown]
# ## 2维曲面生成

# %%
from scipy.sparse import *
import numpy as np

def MyInv(Amat, Vec, FreeDofs:np.ndarray=None):
    '''
        # A is a ngsolve matrix，例如可以如下生成
        A = la.SparseMatrixd.CreateFromCOO([0,1,2], [0,1,2], [1,2,3], 3, 3)
        MyInv(A,BaseVector(np.array([1,2,3])),np.array([1,1,0],dtype=bool))
        gfu.vec.data += BaseVector(MyInv(a.mat,res:BaseVector,np.array(X.FreeDofs())))
        其中FreeDofs的dtype需要时bool才可以
    '''
    if FreeDofs is None:
        FreeDofs = np.array(np.ones(Vec.FV().NumPy().shape),dtype=bool)
    numFree = np.sum(FreeDofs)
    A_data = list(Amat.COO())
    
    A_coo = coo_matrix((A_data[2].NumPy(),(np.array(A_data[0]),np.array(A_data[1]))),Amat.shape)
    A_csr = A_coo.tocsr()
    A_new_csr = A_csr[FreeDofs][:, FreeDofs]
    b = Vec.FV().NumPy()[FreeDofs]
    
    # 使用spsolve求解Ax = b
    x = linalg.spsolve(A_new_csr, b)
    res = np.zeros(FreeDofs.shape)
    res[FreeDofs] = x
    return res

# %%
from netgen.csg import Pnt,SplineCurve2d,CSGeometry,Revolution,Sphere
import numpy as np
import netgen.meshing as ngm
from netgen.csg import *
from netgen.meshing import MeshingStep

# %%
mesh = Mesh('Dumbbell_Sphere.vol')

# %% [markdown]
# ## 有限元空间
# * 标量空间 for multiplier
# * 向量空间 for position and velocity

# %%
fes = H1(mesh,order=1)
fesV = VectorH1(mesh,order=1)
fesMix = fes*fesV

# %% [markdown]
# ## 有限元函数
# * 位置 X
# * 位移 Disp

# %%
Disp = GridFunction(fesV)
X_old = GridFunction(fesV)
Solution = GridFunction(fesMix)

# %% [markdown]
# ## 设定位置X的初值

# %%
Vertices_Coords = np.array([v.point for v in mesh.vertices])
X_old.vec.data = BaseVector(Vertices_Coords.flatten('F'))

# %% [markdown]
# ## Mass lumping on surface

# %%
ir = IntegrationRule(points = [(0,0), (1,0), (0,1)], weights = [1/6, 1/6, 1/6])
ds_lumping = ds(intrules = { TRIG : ir })

# %% [markdown]
# ## Time stepping parameter

# %%
tauval = 0.001
t_old = 0

# %% [markdown]
# ## 显示网格移动的设定

# %%
SetVisualization(deformation=True)

# %%
Draw(Disp,mesh,'disp',deformation=True)

# %% [markdown]
# ## BGN弱形式
# * BGN本身求解的是新时刻的X；这里求解的是D = X^n+1 - X^n

# %%
kappa, D = fesMix.TrialFunction()
chi, eta = fesMix.TestFunction()

lhs = BilinearForm(fesMix)
lhs += InnerProduct(D,specialcf.normal(3))*chi*ds_lumping + tauval*kappa*chi*ds_lumping
lhs += -InnerProduct(eta,specialcf.normal(3))*kappa*ds_lumping + InnerProduct(grad(D).Trace(),grad(eta).Trace())*ds

rhs = LinearForm(fesMix)
rhs += -InnerProduct(grad(X_old).Trace(),grad(eta).Trace())*ds

# %% [markdown]
# ## 时间演化

# %%
t_old = 0
while t_old<0.08:
    mesh.SetDeformation(Disp)
    lhs.Assemble()
    rhs.Assemble()
    # Solution.vec.data = lhs.mat.Inverse(inverse="pardiso")*rhs.vec
    Solution.vec.data = BaseVector(MyInv(lhs.mat, rhs.vec))
    
    Disp.vec.data = BaseVector(Disp.vec.FV().NumPy() + Solution.components[1].vec.FV().NumPy())
    X_old.vec.data = BaseVector(X_old.vec.FV().NumPy() + Solution.components[1].vec.FV().NumPy())
    Redraw()
    # time.sleep(0.001)
    t_old += tauval
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 7
#       5 rhs.Assemble()
#       6 # Solution.vec.data = lhs.mat.Inverse(inverse="pardiso")*rhs.vec
# ----> 7 Solution.vec.data = BaseVector(MyInv(lhs.mat, rhs.vec))
#       9 Disp.vec.data = BaseVector(Disp.vec.FV().NumPy() + Solution.components[1].vec.FV().NumPy())
#      10 X_old.vec.data = BaseVector(X_old.vec.FV().NumPy() + Solution.components[1].vec.FV().NumPy())
#
# Cell In[15], line 18, in MyInv(Amat, Vec, FreeDofs)
#      15 A_data = list(Amat.COO())
#      17 A_coo = coo_matrix((A_data[2].NumPy(),(np.array(A_data[0]),np.array(A_data[1]))),Amat.shape)
# ---> 18 A_csr = A_coo.tocsr()
#      19 A_new_csr = A_csr[FreeDofs][:, FreeDofs]
#      20 b = Vec.FV().NumPy()[FreeDofs]
#
# File ~/opt/anaconda3/envs/ngsolveocc/lib/python3.8/site-packages/scipy/sparse/_coo.py:410, in coo_matrix.tocsr(self, copy)
#     408 x = self._csr_container((data, indices, indptr), shape=self.shape)
#     409 if not self.has_canonical_format:
# --> 410     x.sum_duplicates()
#     411 return x
#
# File ~/opt/anaconda3/envs/ngsolveocc/lib/python3.8/site-packages/scipy/sparse/_compressed.py:1116, in _cs_matrix.sum_duplicates(self)
#    1111 def sum_duplicates(self):
#    1112     """Eliminate duplicate matrix entries by adding them together
#    1113
#    1114     This is an *in place* operation.
#    1115     """
# -> 1116     if self.has_canonical_format:
#    1117         return
#    1118     self.sort_indices()
#
# File ~/opt/anaconda3/envs/ngsolveocc/lib/python3.8/site-packages/scipy/sparse/_compressed.py:1099, in _cs_matrix.__get_has_canonical_format(self)
#    1096     self._has_canonical_format = False
#    1097 elif not hasattr(self, '_has_canonical_format'):
#    1098     self.has_canonical_format = bool(
# -> 1099         _sparsetools.csr_has_canonical_format(
#    1100             len(self.indptr) - 1, self.indptr, self.indices))
#    1101 return self._has_canonical_format
#
# KeyboardInterrupt:
